# %%
"""
A very simple and basic web scraping script. Feel free to
use this as a source of inspiration, but, make sure to attribute
it if you do so.

This is by no means production code.
"""
# built-in imports
import re
import requests
from json import dump

from collections import defaultdict

# user packages
from bs4 import BeautifulSoup
from urllib.request import urlopen

# constants
BASE_URL = "https://www.domain.com.au"
N_PAGES = range(1, 51) # update this to your liking

#https://www.domain.com.au/rent/melbourne-region-vic/?sort=price-desc&page={1}


headers = {"User-Agent": "Mozilla/5.0 (X11; CrOS x86_64 12871.102.0) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/81.0.4044.141 Safari/537.36"}

# begin code
url_links = []
property_metadata = defaultdict(dict)

# generate list of urls to visit
for page in N_PAGES:

    #the full url 
    url = BASE_URL + f"/rent/melbourne-region-vic/?sort=price-desc&page={page}"

    #parse into a BeautifulSoup object
    bs_object = BeautifulSoup(requests.get(url, headers=headers).text, "html.parser")

    # find the unordered list (ul) elements which are the results, then
    # find all href (a) tags that are from the base_url website.
    index_links = bs_object \
        .find(
            "ul",
            {"data-testid": "results"}
        ) \
        .findAll(
            "a",
            href=re.compile(f"{BASE_URL}/*") # the `*` denotes wildcard any
        )

    for link in index_links:
        # if its a property address, add it to the list
        if 'address' in link['class']:
            url_links.append(link['href'])


# for each url, scrape some basic metadata
for property_url in url_links[1:]:

    bs_object = BeautifulSoup(requests.get(property_url, headers=headers).text, "html.parser")

    # looks for the header class to get property name
    property_metadata[property_url]['name'] = bs_object \
        .find("h1", {"class": "css-164r41r"}) \
        .text

    # looks for the div containing a summary title for cost
    property_metadata[property_url]['cost_text'] = bs_object \
        .find("div", {"data-testid": "listing-details__summary-title"}) \
        .text

    # extract coordinates from the hyperlink provided
    # i'll let you figure out what this does :P
    property_metadata[property_url]['coordinates'] = [
        float(coord) for coord in re.findall(
            r'destination=([-\s,\d\.]+)', # use regex101.com here if you need to
            bs_object \
                .find(
                    "a",
                    {"target": "_blank", 'rel': "noopener noreferer"}
                ) \
                .attrs['href']
        )[0].split(',')
    ]

    
    #Keith's note: DEBUGGING INDEX ERROR: try to ignore the IndexError, see if any other error pops up
    rooms_list = []
    for feature in bs_object.find("div", {"data-testid": "property-features"}).findAll("span", {"data-testid": "property-features-text-container"}):
        try:
            rooms_list.append(re.findall(r'\d\s[A-Za-z]+', feature.text)[0])
        except IndexError:
            pass

    property_metadata[property_url]['rooms'] = rooms_list
    
    #Keith's note: below is the code that was actually given but replaced by above
    # property_metadata[property_url]['rooms'] = [
    #     re.findall(r'\d\s[A-Za-z]+', feature.text)[0] for feature in bs_object \
    #         .find("div", {"data-testid": "property-features"}) \
    #         .findAll("span", {"data-testid": "property-features-text-container"})
    # ]

    property_metadata[property_url]['desc'] = re \
        .sub(r'<br\/>', '\n', str(bs_object.find("p"))) \
        .strip('</p>')

# output to example json in data/raw/
with open('../data/raw/example.json', 'w') as f:
    dump(property_metadata, f)

# %%
import pandas as pd
example_data_pd = pd.read_json('../data/raw/example.json').T

# %%
example_data_pd
# Out:
#                                                                                                  name  \
# https://www.domain.com.au/667-glenhuntly-road-c...             667 Glenhuntly Road Caulfield VIC 3162
# https://www.domain.com.au/upstairs-2c-staley-st...       Upstairs 2C Staley Street Brunswick VIC 3056
# https://www.domain.com.au/level-3-302-13-15-lak...  Level 3, 302/13-15 Lake Street Caroline Spring...
# https://www.domain.com.au/3502-14-16-the-esplan...         3502/14-16 The Esplanade St Kilda VIC 3182
# https://www.domain.com.au/9-lansdowne-street-bl...            9 Lansdowne Street Blairgowrie VIC 3942
# ...                                                                                               ...
# https://www.domain.com.au/12-45-marine-parade-s...              12/45 Marine Parade St Kilda VIC 3182
# https://www.domain.com.au/6-5-woorigoleen-rd-to...                 6/5 Woorigoleen Rd Toorak VIC 3142
# https://www.domain.com.au/1a-1b-101-103-main-ro...  1A & 1B/101-103 Main Road West St Albans VIC 3021
# https://www.domain.com.au/3-132-nicholson-stree...     3/132 Nicholson Street Brunswick East VIC 3057
# https://www.domain.com.au/7-oakdene-crescent-ca...               7 Oakdene Crescent Carnegie VIC 3163
#
#                                                                              cost_text  \
# https://www.domain.com.au/667-glenhuntly-road-c...  $38,000 p.a. Incl. Outgoings + GST
# https://www.domain.com.au/upstairs-2c-staley-st...                    $35,000 Annually
# https://www.domain.com.au/level-3-302-13-15-lak...                          4125000 pw
# https://www.domain.com.au/3502-14-16-the-esplan...                              $6,000
# https://www.domain.com.au/9-lansdowne-street-bl...                     $5,000 per week
# ...                                                                                ...
# https://www.domain.com.au/12-45-marine-parade-s...                             $790.00
# https://www.domain.com.au/6-5-woorigoleen-rd-to...                             $790.00
# https://www.domain.com.au/1a-1b-101-103-main-ro...          From $786 - $1572 per week
# https://www.domain.com.au/3-132-nicholson-stree...                             $785.00
# https://www.domain.com.au/7-oakdene-crescent-ca...                                $785
#
#                                                                    coordinates  \
# https://www.domain.com.au/667-glenhuntly-road-c...  [-37.8860233, 145.0173065]
# https://www.domain.com.au/upstairs-2c-staley-st...  [-37.7655919, 144.9633048]
# https://www.domain.com.au/level-3-302-13-15-lak...  [-37.7316459, 144.7446886]
# https://www.domain.com.au/3502-14-16-the-esplan...  [-37.8650177, 144.9746821]
# https://www.domain.com.au/9-lansdowne-street-bl...   [-38.372703, 144.7856897]
# ...                                                                        ...
# https://www.domain.com.au/12-45-marine-parade-s...    [-37.874449, 144.977025]
# https://www.domain.com.au/6-5-woorigoleen-rd-to...  [-37.8429886, 145.0169363]
# https://www.domain.com.au/1a-1b-101-103-main-ro...    [-37.756201, 144.811242]
# https://www.domain.com.au/3-132-nicholson-stree...   [-37.7670198, 144.980567]
# https://www.domain.com.au/7-oakdene-crescent-ca...  [-37.8888193, 145.0652951]
#
#                                                                            rooms  \
# https://www.domain.com.au/667-glenhuntly-road-c...                            []
# https://www.domain.com.au/upstairs-2c-staley-st...  [0 Beds, 0 Baths, 2 Parking]
# https://www.domain.com.au/level-3-302-13-15-lak...                            []
# https://www.domain.com.au/3502-14-16-the-esplan...  [3 Beds, 3 Baths, 3 Parking]
# https://www.domain.com.au/9-lansdowne-street-bl...  [3 Beds, 2 Baths, 3 Parking]
# ...                                                                          ...
# https://www.domain.com.au/12-45-marine-parade-s...  [2 Beds, 2 Baths, 2 Parking]
# https://www.domain.com.au/6-5-woorigoleen-rd-to...  [3 Beds, 2 Baths, 2 Parking]
# https://www.domain.com.au/1a-1b-101-103-main-ro...    [1 Bed, 1 Bath, 9 Parking]
# https://www.domain.com.au/3-132-nicholson-stree...  [3 Beds, 2 Baths, 2 Parking]
# https://www.domain.com.au/7-oakdene-crescent-ca...  [5 Beds, 3 Baths, 3 Parking]
#
#                                                                                                  desc
# https://www.domain.com.au/667-glenhuntly-road-c...           Can you hear it? Opportunity knocking!!
# https://www.domain.com.au/upstairs-2c-staley-st...  1st floor offices/studios\nEasy walking distan...
# https://www.domain.com.au/level-3-302-13-15-lak...  - Centrally located with tranquil views.\n- Le...
# https://www.domain.com.au/3502-14-16-the-esplan...  Inspired by the interplay of timeless design a...
# https://www.domain.com.au/9-lansdowne-street-bl...        Phone enquiry code for this property : 2751
# ...                                                                                               ...
# https://www.domain.com.au/12-45-marine-parade-s...                                       Louisa Corke
# https://www.domain.com.au/6-5-woorigoleen-rd-to...   class="css-dxogle">* Unverified feature<svg a...
# https://www.domain.com.au/1a-1b-101-103-main-ro...  Total floor area 878m2.\nNett office area 780m...
# https://www.domain.com.au/3-132-nicholson-stree...  An opportunity exists to lease what is arguabl...
# https://www.domain.com.au/7-oakdene-crescent-ca...  Beautifully presented, renovated Family Home. ...
#
# [999 rows x 5 columns]
